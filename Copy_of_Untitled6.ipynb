# %% [markdown]
# <a href="https://colab.research.google.com/github/dg3103/Housing-Project/blob/main/Copy_of_Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =pd.read_csv('/content/drive/MyDrive/data/result.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               business_id  ... attributes/Open24Hours
# 0  6iYb2HFDywm3zjuRg0shjw  ...                    NaN
# 1  tCbdrRPZA0oiIYSmHG3J0w  ...                    NaN
# 2  bvN78flM8NLprQ1a1y5dRg  ...                    NaN
# 3  oaepsyvc0J17qwi8cfrOWg  ...                    NaN
# 4  PE9uqAjdw0E4-8mjGl3wVA  ...                    NaN
#
# [5 rows x 60 columns]

# %%
df.sort_values(by="city", kind=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-8dd2011e4289> in <module>()
# ----> 1 df.sort_values(by="city", kind="New York")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5306
#    5307             indexer = nargsort(
# -> 5308                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5309             )
#    5310
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key)
#     299         non_nans = non_nans[::-1]
#     300         non_nan_idx = non_nan_idx[::-1]
# --> 301     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     302     if not ascending:
#     303         indexer = indexer[::-1]
#
# ValueError: sort kind must be one of 'quick', 'heap', or 'stable' (got 'New York')
